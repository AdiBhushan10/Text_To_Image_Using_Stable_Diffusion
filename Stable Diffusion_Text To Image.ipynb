# %%
import torch
print(torch.__version__)
print(torch.cuda.get_device_name(0))
# Out:
# 2.5.1+cu124
# NVIDIA GeForce RTX 3070 Laptop GPU

# %%
# !pip install --upgrade git+https://github.com/huggingface/diffusers.git transformers accelerate scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/huggingface/diffusers.git
#   Cloning https://github.com/huggingface/diffusers.git to c:\users\kingx\appdata\local\temp\pip-req-build-t85w9q87
#   Resolved https://github.com/huggingface/diffusers.git to commit 02cbe972c3013a596c422b8cc0ca1e872f2eb647
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: transformers in c:\users\kingx\appdata\roaming\python\python310\site-packages (4.47.0)
# Requirement already satisfied: accelerate in c:\users\kingx\appdata\roaming\python\python310\site-packages (1.2.1)
# Requirement already satisfied: scipy in c:\users\kingx\appdata\roaming\python\python310\site-packages (1.14.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from diffusers==0.32.0.dev0) (2.28.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from diffusers==0.32.0.dev0) (2022.7.9)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\kingx\appdata\roaming\python\python310\site-packages (from diffusers==0.32.0.dev0) (0.4.5)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from diffusers==0.32.0.dev0) (3.9.0)
# Requirement already satisfied: numpy in c:\users\kingx\appdata\roaming\python\python310\site-packages (from diffusers==0.32.0.dev0) (2.0.2)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from diffusers==0.32.0.dev0) (9.4.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in c:\users\kingx\appdata\roaming\python\python310\site-packages (from diffusers==0.32.0.dev0) (0.26.5)
# Requirement already satisfied: importlib_metadata in c:\programdata\anaconda3\lib\site-packages (from diffusers==0.32.0.dev0) (4.11.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\kingx\appdata\roaming\python\python310\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from transformers) (22.0)
# Requirement already satisfied: tqdm>=4.27 in c:\programdata\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\kingx\appdata\roaming\python\python310\site-packages (from accelerate) (2.5.1)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kingx\appdata\roaming\python\python310\site-packages (from huggingface-hub>=0.23.2->diffusers==0.32.0.dev0) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kingx\appdata\roaming\python\python310\site-packages (from huggingface-hub>=0.23.2->diffusers==0.32.0.dev0) (2024.10.0)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\kingx\appdata\roaming\python\python310\site-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (2.8.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.2.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib_metadata->diffusers==0.32.0.dev0) (3.11.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->diffusers==0.32.0.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->diffusers==0.32.0.dev0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->diffusers==0.32.0.dev0) (2023.7.22)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->diffusers==0.32.0.dev0) (1.26.14)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.1)
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git 'C:\Users\KingX\AppData\Local\Temp\pip-req-build-t85w9q87'

# %%
pip install transformers[torch]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transformers[torch]
#   Downloading transformers-4.47.0-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from transformers[torch]) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from transformers[torch]) (0.26.5)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from transformers[torch]) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from transformers[torch]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from transformers[torch]) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from transformers[torch]) (2024.9.11)
# Requirement already satisfied: requests in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from transformers[torch]) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers[torch])
#   Downloading tokenizers-0.21.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: safetensors>=0.4.1 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from transformers[torch]) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from transformers[torch]) (4.67.1)
# Requirement already satisfied: torch in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from transformers[torch]) (2.0.1)
# Collecting accelerate>=0.26.0 (from transformers[torch])
#   Downloading accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from accelerate>=0.26.0->transformers[torch]) (5.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers[torch]) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers[torch]) (4.11.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from torch->transformers[torch]) (1.13.3)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from torch->transformers[torch]) (3.2.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from torch->transformers[torch]) (2.11.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from tqdm>=4.27->transformers[torch]) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from requests->transformers[torch]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from requests->transformers[torch]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from requests->transformers[torch]) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from requests->transformers[torch]) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from jinja2->torch->transformers[torch]) (1.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\envs\gputesttorch\lib\site-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Downloading accelerate-1.2.1-py3-none-any.whl (336 kB)
# Downloading tokenizers-0.21.0-cp39-abi3-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 33.8 MB/s eta 0:00:00
# Downloading transformers-4.47.0-py3-none-any.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ------------------------------- -------- 7.9/10.1 MB 48.7 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.1 MB 22.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 18.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 15.0 MB/s eta 0:00:00
# Installing collected packages: tokenizers, accelerate, transformers
# Successfully installed accelerate-1.2.1 tokenizers-0.21.0 transformers-4.47.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts accelerate-config.exe, accelerate-estimate-memory.exe, accelerate-launch.exe, accelerate-merge-weights.exe and accelerate.exe are installed in 'C:\Users\KingX\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transformers-cli.exe is installed in 'C:\Users\KingX\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler

# %%
import torch
model_id = "stabilityai/stable-diffusion-2"
scheduler= EulerDiscreteScheduler.from_pretrained(model_id,subfolder="scheduler")
pipe=StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler)
pipe = pipe.to("cuda")
# Out:
# Loading pipeline components...: 100%|████████████████████████████████████████████████████| 6/6 [00:00<00:00, 25.31it/s]

# %%
prompt="a photo of astronaut in the ocean"
image=pipe(prompt, height=768, width=768).images[0]
image.save("SD Img1.png")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:31<00:00,  1.61it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=768x768>
